# %%
import networkx as nx 
import matplotlib.pyplot as plt
G=nx.DiGraph() 
G.add_edge('UU Nomor 40 Tahun 1999','UUD 1945') 
G.add_edge('UU Nomor 40 Tahun 1999','Ketetapan MPR Nomor XVII/MPR/1998')

G.add_edge('UU Nomor 19 Tahun 2016','UUD 1945')
G.add_edge('UU Nomor 19 Tahun 2016','UU Nomor 11 Tahun 2008')

G.add_edge('UU Nomor 44 Tahun 2009','UUD 1945')

G.add_edge('UU Nomor 9 Tahun 2019','UUD 1945')

G.add_edge('UU Nomor 18 Tahun 2017','UUD 1945')
G.add_edge('UU Nomor 18 Tahun 2017','UU Nomor 13 Tahun 2003')
G.add_edge('UU Nomor 18 Tahun 2017','UU Nomor 6 Tahun 2012')

G.add_edge('UU Nomor 38 Tahun 2014','UUD 1945')

G.add_edge('UU Nomor 1 Tahun 1984','UUD 1945')
G.add_edge('UU Nomor 1 Tahun 1984','Ketetapan MPR Nomor II/MPR/1983')
G.add_edge('UU Nomor 1 Tahun 1984','Ketetapan MPR Nomor VII/MPR/1983')
G.add_edge('UU Nomor 1 Tahun 1984','Staatsblad Tahun 1925 Nomor 448')

G.add_edge('UU Nomor 13 Tahun 2003','UUD 1945')

G.add_edge('UU Nomor 36 Tahun 2009','UUD 1945')

G.add_edge('UU Nomor 11 Tahun 2008','UUD 1945')

nx.draw_networkx(G)
plt.axis('off')
plt.show() # display
